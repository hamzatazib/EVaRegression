# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime

# %% [markdown]
# # Test MSE Plots

# %% [markdown]
# ## $\alpha=0.7$

# %%
x = ["Housing", "Concrete", "Auto MPG"]
y = [0.365, 0.355, 0.323, 0.321, 0.365, 0.365] # Housing
z = [0.421, 0.418, 0.441, 0.441, 0.438, 0.437] # Concrete
k = [0.264, 0.312, 0.273, 0.272, 0.291, 0.290] # Auto MPG
for i in range(1, 7):
    vars()[f"y_{i}"] = [y[i-1], z[i-1], k[i-1]]

labels = ["Ridge Regression (RR)", "Stable Regression", "EVaR $ℓ_1$ Random WS", "EVaR $ℓ_1$ RR WS", "EVaR $ℓ_2$ Random WS", "EVaR $ℓ_2$ RR WS"]
colors = ["black","grey","darkgreen","seagreen","firebrick","lightcoral"]
width = 0.8
def subcategorybar(X, vals, width, labels, colors):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", label=labels[i], color=colors[i])   
    plt.xticks(_X, X, fontsize=16)
    plt.ylabel("Mean Squared Error (MSE) on Test set", fontsize=16)
    plt.ylim(0.2, 0.45)

plt.figure(figsize=(14,8))
subcategorybar(x, [y_1, y_2, y_3, y_4, y_5, y_6], width, labels, colors)
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# ## $\alpha = 0.6$

# %%
x = ["Housing", "Concrete", "Auto MPG"]
y = [0.336, 0.322, 0.381, 0.379, 0.456, 0.455] # Housing
z = [0.421, 0.416, 0.428, 0.427, 0.440, 0.438] # Concrete
k = [0.264, 0.292, 0.341, 0.335, 0.282, 0.281] # Auto MPG
for i in range(1, 7):
    vars()[f"y_{i}"] = [y[i-1], z[i-1], k[i-1]]

labels = ["Ridge Regression (RR)", "Stable Regression", "EVaR $ℓ_1$ Random WS", 
          "EVaR $ℓ_1$ RR WS", "EVaR $ℓ_2$ Random WS", "EVaR $ℓ_2$ RR WS"]
colors = ["black","grey","darkgreen","seagreen","firebrick","lightcoral"]
width = 0.8
def subcategorybar(X, vals, width, labels, colors):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", label=labels[i], color=colors[i])   
    plt.xticks(_X, X, fontsize=16)
    plt.ylabel("Mean Squared Error (MSE) on Test set", fontsize=16)
    plt.ylim(0.2, 0.50)

plt.figure(figsize=(14,8))
subcategorybar(x, [y_1, y_2, y_3, y_4, y_5, y_6], width, labels, colors)
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# ## $\alpha = 0.5$

# %%
x = ["Housing", "Concrete", "Auto MPG"]
y = [0.337, 0.319, 0.381, 0.379, 0.456, 0.455] # Housing
z = [0.421, 0.418, 0.430, 0.427, 0.445, 0.441] # Concrete
k = [0.234, 0.290, 0.330, 0.327, 0.275, 0.242] # Auto MPG
for i in range(1, 7):
    vars()[f"y_{i}"] = [y[i-1], z[i-1], k[i-1]]

labels = ["Ridge Regression (RR)", "Stable Regression", "EVaR $ℓ_1$ Random WS", 
          "EVaR $ℓ_1$ RR WS", "EVaR $ℓ_2$ Random WS", "EVaR $ℓ_2$ RR WS"]
colors = ["black","grey","darkgreen","seagreen","firebrick","lightcoral"]
width = 0.8
def subcategorybar(X, vals, width, labels, colors):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", label=labels[i], color=colors[i])   
    plt.xticks(_X, X, fontsize=16)
    plt.ylabel("Mean Squared Error (MSE) on Test set", fontsize=16)
    plt.ylim(0.2, 0.5)

plt.figure(figsize=(14,8))
subcategorybar(x, [y_1, y_2, y_3, y_4, y_5, y_6], width, labels, colors)
plt.legend(fontsize=16)

plt.show()

# %% [markdown]
# # Test MSE Plots with Outliers

# %% [markdown]
# ## $\alpha=0.7$

# %%
x = ["Housing", "Concrete", "Auto MPG"]
y = [0.452, 0.406, 0.365, 0.462] # Housing
z = [0.470, 0.429, 0.453, 0.487] # Concrete
k = [0.269, 0.295, 0.265, 0.305] # Auto MPG
for i in range(1, 5):
    vars()[f"y_out_{i}"] = [y[i-1], z[i-1], k[i-1]]

labels = ["Ridge Regression (RR)", "Stable Regression", "EVaR $ℓ_1$ RR WS", "EVaR $ℓ_2$ RR WS"]
colors = ["black","grey","darkgreen","firebrick"]
width = 0.8
def subcategorybar(X, vals, width, labels, colors):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", label=labels[i], color=colors[i])   
    plt.xticks(_X, X, fontsize=16)
    plt.ylabel("Mean Squared Error (MSE) on Test set", fontsize=16)
    plt.ylim(0.2, 0.5)

plt.figure(figsize=(14,8))
subcategorybar(x, [y_out_1, y_out_2, y_out_3, y_out_4], width, labels, colors)
plt.legend(fontsize=16)

plt.show()

# %%
for i, list_values in enumerate([y, z, k]):
    perc_improv = round(100*(list_values[1] - list_values[2])/list_values[1], 2)
    print(f"Percentage improvement of EVaR ℓ_1 vs. Stable Regression on {x[i]} dataset: {perc_improv} %")
print("------------------------------------------------------------------")
for i, list_values in enumerate([y, z, k]):
    perc_improv = round(100*(list_values[1] - list_values[3])/list_values[1], 2)
    print(f"Percentage improvement of EVaR ℓ_2 vs. Stable Regression on {x[i]} dataset: {perc_improv} %")
# Out:
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Housing dataset: 10.1 %
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Concrete dataset: -5.59 %
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Auto MPG dataset: 10.17 %
# ------------------------------------------------------------------
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Housing dataset: -13.79 %
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Concrete dataset: -13.52 %
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Auto MPG dataset: -3.39 %

# %% [markdown]
# ## $\alpha=0.6$

# %%
x = ["Housing", "Concrete", "Auto MPG"]
y = [0.447, 0.397, 0.383, 0.464] # Housing
z = [0.460, 0.423, 0.477, 0.493] # Concrete
k = [0.269, 0.292, 0.273, 0.296] # Auto MPG
for i in range(1, 5):
    vars()[f"y_out_{i}"] = [y[i-1], z[i-1], k[i-1]]

labels = ["Ridge Regression (RR)", "Stable Regression", "EVaR $ℓ_1$ RR WS", "EVaR $ℓ_2$ RR WS"]
colors = ["black","grey","darkgreen","firebrick"]
width = 0.8
def subcategorybar(X, vals, width, labels, colors):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", label=labels[i], color=colors[i])   
    plt.xticks(_X, X, fontsize=16)
    plt.ylabel("Mean Squared Error (MSE) on Test set", fontsize=16)
    plt.ylim(0.2, 0.5)

plt.figure(figsize=(14,8))
subcategorybar(x, [y_out_1, y_out_2, y_out_3, y_out_4], width, labels, colors)
plt.legend(fontsize=16)

plt.show()

# %%
for i, list_values in enumerate([y, z, k]):
    perc_improv = round(100*(list_values[1] - list_values[2])/list_values[1], 2)
    print(f"Percentage improvement of EVaR ℓ_1 vs. Stable Regression on {x[i]} dataset: {perc_improv} %")
print("------------------------------------------------------------------")
for i, list_values in enumerate([y, z, k]):
    perc_improv = round(100*(list_values[1] - list_values[3])/list_values[1], 2)
    print(f"Percentage improvement of EVaR ℓ_2 vs. Stable Regression on {x[i]} dataset: {perc_improv} %")
# Out:
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Housing dataset: 3.53 %
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Concrete dataset: -12.77 %
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Auto MPG dataset: 6.51 %
# ------------------------------------------------------------------
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Housing dataset: -16.88 %
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Concrete dataset: -16.55 %
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Auto MPG dataset: -1.37 %

# %% [markdown]
# ## $\alpha=0.5$

# %%
x = ["Housing", "Concrete", "Auto MPG"]
y = [0.444, 0.402, 0.384, 0.456] # Housing
z = [0.451, 0.426, 0.464, 0.496] # Concrete
k = [0.269, 0.294, 0.306, 0.274] # Auto MPG
for i in range(1, 5):
    vars()[f"y_out_{i}"] = [y[i-1], z[i-1], k[i-1]]

labels = ["Ridge Regression (RR)", "Stable Regression", "EVaR $ℓ_1$ RR WS", "EVaR $ℓ_2$ RR WS"]
colors = ["black","grey","darkgreen","firebrick"]
width = 0.8
def subcategorybar(X, vals, width, labels, colors):
    n = len(vals)
    _X = np.arange(len(X))
    for i in range(n):
        plt.bar(_X - width/2. + i/float(n)*width, vals[i], 
                width=width/float(n), align="edge", label=labels[i], color=colors[i])   
    plt.xticks(_X, X, fontsize=16)
    plt.ylabel("Mean Squared Error (MSE) on Test set", fontsize=16)
    plt.ylim(0.2, 0.5)

plt.figure(figsize=(14,8))
subcategorybar(x, [y_out_1, y_out_2, y_out_3, y_out_4], width, labels, colors)
plt.legend(fontsize=16)

plt.show()

# %%
for i, list_values in enumerate([y, z, k]):
    perc_improv = round(100*(list_values[1] - list_values[2])/list_values[1], 2)
    print(f"Percentage improvement of EVaR ℓ_1 vs. Stable Regression on {x[i]} dataset: {perc_improv} %")
print("------------------------------------------------------------------")
for i, list_values in enumerate([y, z, k]):
    perc_improv = round(100*(list_values[1] - list_values[3])/list_values[1], 2)
    print(f"Percentage improvement of EVaR ℓ_2 vs. Stable Regression on {x[i]} dataset: {perc_improv} %")
# Out:
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Housing dataset: 4.48 %
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Concrete dataset: -8.92 %
# Percentage improvement of EVaR ℓ_1 vs. Stable Regression on Auto MPG dataset: -4.08 %
# ------------------------------------------------------------------
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Housing dataset: -13.43 %
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Concrete dataset: -16.43 %
# Percentage improvement of EVaR ℓ_2 vs. Stable Regression on Auto MPG dataset: 6.8 %
